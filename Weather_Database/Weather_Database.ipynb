# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vila velha
# Processing Record 2 of Set 1 | el llano
# Processing Record 3 of Set 1 | atlantic beach
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | akureyri
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | las palmas
# Processing Record 10 of Set 1 | waipawa
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | clarence town
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | santa ana
# Processing Record 18 of Set 1 | chanika
# Processing Record 19 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 1 | karpathos
# Processing Record 21 of Set 1 | ca mau
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | luena
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | lebork
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 1 | svetlogorsk
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | angoram
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | san patricio
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | tomatlan
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | labuan
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | road town
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | burica
# City not found. Skipping...
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | paamiut
# Processing Record 6 of Set 2 | tachov
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | aberdeen
# Processing Record 10 of Set 2 | wanxian
# Processing Record 11 of Set 2 | brae
# Processing Record 12 of Set 2 | avarua
# Processing Record 13 of Set 2 | terracina
# Processing Record 14 of Set 2 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 15 of Set 2 | ostrovnoy
# Processing Record 16 of Set 2 | marawi
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | oktyabrskoye
# Processing Record 22 of Set 2 | gigmoto
# Processing Record 23 of Set 2 | coahuayana
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | mareeba
# Processing Record 26 of Set 2 | dzyhivka
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | tabas
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | gat
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | jardim
# Processing Record 34 of Set 2 | quesnel
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | kijang
# Processing Record 37 of Set 2 | dukat
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | ewa beach
# Processing Record 40 of Set 2 | zamora
# Processing Record 41 of Set 2 | butia
# Processing Record 42 of Set 2 | ridgecrest
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | sao felix do xingu
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | karasjok
# Processing Record 48 of Set 2 | enshi
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | darhan
# Processing Record 3 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 3 | kuandian
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | harper
# Processing Record 10 of Set 3 | praia da vitoria
# Processing Record 11 of Set 3 | kapit
# Processing Record 12 of Set 3 | nong phai
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | nakamura
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | isla vista
# Processing Record 17 of Set 3 | talara
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | shimoda
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | hella
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 3 | bustonkala
# City not found. Skipping...
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | vanatori-neamt
# Processing Record 33 of Set 3 | healdsburg
# Processing Record 34 of Set 3 | bardiyah
# Processing Record 35 of Set 3 | dandong
# Processing Record 36 of Set 3 | rumoi
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | flin flon
# Processing Record 42 of Set 3 | teahupoo
# Processing Record 43 of Set 3 | yining
# Processing Record 44 of Set 3 | basco
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | tateyama
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | meridian
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | fukagawa
# Processing Record 2 of Set 4 | iquique
# Processing Record 3 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 4 | carutapera
# Processing Record 5 of Set 4 | saint-georges
# Processing Record 6 of Set 4 | acapulco
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | nouadhibou
# Processing Record 9 of Set 4 | yar-sale
# Processing Record 10 of Set 4 | challans
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | kaeo
# Processing Record 13 of Set 4 | hirara
# Processing Record 14 of Set 4 | bozoum
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | mogadishu
# Processing Record 17 of Set 4 | burnie
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | joue-les-tours
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | jamestown
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | port keats
# Processing Record 25 of Set 4 | rio grande
# Processing Record 26 of Set 4 | namatanai
# Processing Record 27 of Set 4 | shamary
# Processing Record 28 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 4 | bandar-e lengeh
# Processing Record 30 of Set 4 | upata
# Processing Record 31 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 4 | kununurra
# Processing Record 33 of Set 4 | mercedes
# Processing Record 34 of Set 4 | oume
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 4 | hudiksvall
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | batagay-alyta
# Processing Record 40 of Set 4 | pachperwa
# Processing Record 41 of Set 4 | shenjiamen
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | pudozh
# Processing Record 45 of Set 4 | dourbali
# Processing Record 46 of Set 4 | makakilo city
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 4 | avera
# Processing Record 1 of Set 5 | saint-leu
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | kutum
# Processing Record 4 of Set 5 | yazykovo
# Processing Record 5 of Set 5 | puerto escondido
# Processing Record 6 of Set 5 | fallon
# Processing Record 7 of Set 5 | yablochnyy
# Processing Record 8 of Set 5 | fort-shevchenko
# Processing Record 9 of Set 5 | fairview
# Processing Record 10 of Set 5 | krasnyye barrikady
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | aykhal
# Processing Record 14 of Set 5 | magadan
# Processing Record 15 of Set 5 | pafos
# Processing Record 16 of Set 5 | fernie
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | salmas
# Processing Record 19 of Set 5 | fuerte olimpo
# Processing Record 20 of Set 5 | luwuk
# Processing Record 21 of Set 5 | luba
# Processing Record 22 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 5 | atar
# Processing Record 24 of Set 5 | vardo
# Processing Record 25 of Set 5 | estelle
# Processing Record 26 of Set 5 | kem
# Processing Record 27 of Set 5 | esperance
# Processing Record 28 of Set 5 | chingirlau
# Processing Record 29 of Set 5 | shingu
# Processing Record 30 of Set 5 | kathu
# Processing Record 31 of Set 5 | igrim
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | marsh harbour
# Processing Record 35 of Set 5 | mbandaka
# Processing Record 36 of Set 5 | biak
# Processing Record 37 of Set 5 | abeche
# Processing Record 38 of Set 5 | nakhon thai
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | muriwai beach
# Processing Record 41 of Set 5 | dikson
# Processing Record 42 of Set 5 | bacolod
# Processing Record 43 of Set 5 | san policarpo
# Processing Record 44 of Set 5 | bushehr
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | komsomolskiy
# Processing Record 47 of Set 5 | gwadar
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | peace river
# Processing Record 50 of Set 5 | naze
# Processing Record 1 of Set 6 | calama
# Processing Record 2 of Set 6 | vao
# Processing Record 3 of Set 6 | ugoofaaru
# Processing Record 4 of Set 6 | ust-nera
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 6 | lagoa
# Processing Record 8 of Set 6 | yingkou
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | san quintin
# Processing Record 11 of Set 6 | conde
# Processing Record 12 of Set 6 | yueyang
# Processing Record 13 of Set 6 | tiksi
# Processing Record 14 of Set 6 | ulaangom
# Processing Record 15 of Set 6 | monte santo
# Processing Record 16 of Set 6 | omboue
# Processing Record 17 of Set 6 | north bend
# Processing Record 18 of Set 6 | te horo
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | chichli
# Processing Record 21 of Set 6 | staryy nadym
# Processing Record 22 of Set 6 | helong
# Processing Record 23 of Set 6 | vryburg
# Processing Record 24 of Set 6 | asfi
# Processing Record 25 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 26 of Set 6 | mayo
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | aksu
# Processing Record 30 of Set 6 | sukumo
# Processing Record 31 of Set 6 | sakaiminato
# Processing Record 32 of Set 6 | laredo
# Processing Record 33 of Set 6 | viseu
# Processing Record 34 of Set 6 | havoysund
# Processing Record 35 of Set 6 | bolivar
# Processing Record 36 of Set 6 | uyemskiy
# Processing Record 37 of Set 6 | dawlatabad
# Processing Record 38 of Set 6 | berlevag
# Processing Record 39 of Set 6 | araouane
# Processing Record 40 of Set 6 | carnarvon
# Processing Record 41 of Set 6 | lazaro cardenas
# Processing Record 42 of Set 6 | ternate
# Processing Record 43 of Set 6 | henties bay
# Processing Record 44 of Set 6 | evensk
# Processing Record 45 of Set 6 | lanigan
# Processing Record 46 of Set 6 | malanville
# Processing Record 47 of Set 6 | pitimbu
# Processing Record 48 of Set 6 | mahibadhoo
# Processing Record 49 of Set 6 | grootfontein
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | karratha
# Processing Record 2 of Set 7 | standerton
# Processing Record 3 of Set 7 | warwick
# Processing Record 4 of Set 7 | grindavik
# Processing Record 5 of Set 7 | wukari
# Processing Record 6 of Set 7 | tangshan
# Processing Record 7 of Set 7 | ojinaga
# Processing Record 8 of Set 7 | dauphin
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | manadhoo
# Processing Record 11 of Set 7 | disa
# Processing Record 12 of Set 7 | zyryanka
# Processing Record 13 of Set 7 | mount isa
# Processing Record 14 of Set 7 | victoria
# Processing Record 15 of Set 7 | pinawa
# Processing Record 16 of Set 7 | hofn
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | igarka
# Processing Record 19 of Set 7 | anderson
# Processing Record 20 of Set 7 | tasiilaq
# Processing Record 21 of Set 7 | chandrakona
# Processing Record 22 of Set 7 | severo-yeniseyskiy
# Processing Record 23 of Set 7 | bereda
# Processing Record 24 of Set 7 | poindimie
# Processing Record 25 of Set 7 | tarko-sale
# Processing Record 26 of Set 7 | luganville
# Processing Record 27 of Set 7 | sept-iles
# Processing Record 28 of Set 7 | kandrian
# Processing Record 29 of Set 7 | mumford
# Processing Record 30 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 7 | jiayuguan
# Processing Record 32 of Set 7 | salalah
# Processing Record 33 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 7 | broken hill
# Processing Record 35 of Set 7 | uttukkuli
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | mazatlan
# Processing Record 38 of Set 7 | bredasdorp
# Processing Record 39 of Set 7 | tafo
# Processing Record 40 of Set 7 | simpang
# Processing Record 41 of Set 7 | labis
# Processing Record 42 of Set 7 | santa rosa
# Processing Record 43 of Set 7 | tatawin
# Processing Record 44 of Set 7 | sao filipe
# Processing Record 45 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 7 | storm lake
# Processing Record 47 of Set 7 | fare
# Processing Record 48 of Set 7 | nome
# Processing Record 49 of Set 7 | banda aceh
# Processing Record 50 of Set 7 | bellavista
# Processing Record 1 of Set 8 | betlitsa
# Processing Record 2 of Set 8 | bongandanga
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 8 | churapcha
# Processing Record 6 of Set 8 | gari
# Processing Record 7 of Set 8 | shangzhi
# Processing Record 8 of Set 8 | barcelos
# Processing Record 9 of Set 8 | morondava
# Processing Record 10 of Set 8 | somerset east
# Processing Record 11 of Set 8 | chuy
# Processing Record 12 of Set 8 | port elizabeth
# Processing Record 13 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 8 | mineiros
# Processing Record 15 of Set 8 | taltal
# Processing Record 16 of Set 8 | ancud
# Processing Record 17 of Set 8 | atambua
# Processing Record 18 of Set 8 | sortland
# Processing Record 19 of Set 8 | lumphat
# Processing Record 20 of Set 8 | saint george
# Processing Record 21 of Set 8 | dongsheng
# Processing Record 22 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 8 | padre paraiso
# Processing Record 24 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 8 | derzhavinsk
# Processing Record 26 of Set 8 | baijiantan
# Processing Record 27 of Set 8 | ambilobe
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | batagay
# Processing Record 30 of Set 8 | zmeinogorsk
# Processing Record 31 of Set 8 | svetlaya
# Processing Record 32 of Set 8 | ust-kuyga
# Processing Record 33 of Set 8 | ampanihy
# Processing Record 34 of Set 8 | los llanos de aridane
# Processing Record 35 of Set 8 | banning
# Processing Record 36 of Set 8 | uvalde
# Processing Record 37 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 8 | ometepec
# Processing Record 39 of Set 8 | chilliwack
# Processing Record 40 of Set 8 | kalabo
# Processing Record 41 of Set 8 | borgo san lorenzo
# Processing Record 42 of Set 8 | apricena
# Processing Record 43 of Set 8 | kawalu
# Processing Record 44 of Set 8 | mayumba
# Processing Record 45 of Set 8 | gizo
# Processing Record 46 of Set 8 | sambava
# Processing Record 47 of Set 8 | hazorasp
# Processing Record 48 of Set 8 | kudahuvadhoo
# Processing Record 49 of Set 8 | lavrentiya
# Processing Record 50 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | axim
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | lojt kirkeby
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 9 | longview
# Processing Record 7 of Set 9 | worland
# Processing Record 8 of Set 9 | popondetta
# Processing Record 9 of Set 9 | severnyy
# Processing Record 10 of Set 9 | abu dhabi
# Processing Record 11 of Set 9 | ishigaki
# Processing Record 12 of Set 9 | provideniya
# Processing Record 13 of Set 9 | san rafael
# Processing Record 14 of Set 9 | mackay
# Processing Record 15 of Set 9 | maroua
# Processing Record 16 of Set 9 | la ronge
# Processing Record 17 of Set 9 | palu
# Processing Record 18 of Set 9 | itoman
# Processing Record 19 of Set 9 | laguna
# Processing Record 20 of Set 9 | banjarmasin
# Processing Record 21 of Set 9 | redmond
# Processing Record 22 of Set 9 | leningradskiy
# Processing Record 23 of Set 9 | tunxi
# City not found. Skipping...
# Processing Record 24 of Set 9 | port hardy
# Processing Record 25 of Set 9 | say
# Processing Record 26 of Set 9 | honiara
# Processing Record 27 of Set 9 | phibun mangsahan
# Processing Record 28 of Set 9 | kalmunai
# Processing Record 29 of Set 9 | kolondieba
# Processing Record 30 of Set 9 | bukama
# Processing Record 31 of Set 9 | mega
# Processing Record 32 of Set 9 | wakkanai
# Processing Record 33 of Set 9 | palmer
# Processing Record 34 of Set 9 | zwedru
# Processing Record 35 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 9 | stromness
# Processing Record 38 of Set 9 | kafue
# Processing Record 39 of Set 9 | hambantota
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | portarlington
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | aklavik
# Processing Record 44 of Set 9 | madimba
# Processing Record 45 of Set 9 | verkhoyansk
# Processing Record 46 of Set 9 | zalantun
# Processing Record 47 of Set 9 | te anau
# Processing Record 48 of Set 9 | geraldton
# Processing Record 49 of Set 9 | wawa
# Processing Record 50 of Set 9 | nuevo casas grandes
# Processing Record 1 of Set 10 | otjimbingwe
# Processing Record 2 of Set 10 | bloemhof
# Processing Record 3 of Set 10 | tabou
# Processing Record 4 of Set 10 | neyshabur
# Processing Record 5 of Set 10 | kampot
# Processing Record 6 of Set 10 | oudtshoorn
# Processing Record 7 of Set 10 | kahului
# Processing Record 8 of Set 10 | gopalganj
# Processing Record 9 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 10 | muros
# Processing Record 11 of Set 10 | arshan
# Processing Record 12 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | zabol
# Processing Record 15 of Set 10 | dobryatino
# Processing Record 16 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 17 of Set 10 | bila tserkva
# Processing Record 18 of Set 10 | goundi
# Processing Record 19 of Set 10 | angoche
# Processing Record 20 of Set 10 | aiquile
# Processing Record 21 of Set 10 | pocoes
# Processing Record 22 of Set 10 | chipinge
# Processing Record 23 of Set 10 | ucluelet
# Processing Record 24 of Set 10 | tiznit
# Processing Record 25 of Set 10 | dicabisagan
# Processing Record 26 of Set 10 | talcahuano
# Processing Record 27 of Set 10 | raiganj
# Processing Record 28 of Set 10 | severomuysk
# Processing Record 29 of Set 10 | neiafu
# Processing Record 30 of Set 10 | eyrarbakki
# Processing Record 31 of Set 10 | nyurba
# Processing Record 32 of Set 10 | villa carlos paz
# Processing Record 33 of Set 10 | morrope
# Processing Record 34 of Set 10 | praya
# Processing Record 35 of Set 10 | punta gorda
# Processing Record 36 of Set 10 | marly
# Processing Record 37 of Set 10 | saldanha
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | deputatskiy
# Processing Record 40 of Set 10 | platanos
# Processing Record 41 of Set 10 | kolosovka
# Processing Record 42 of Set 10 | avanigadda
# Processing Record 43 of Set 10 | tiarei
# Processing Record 44 of Set 10 | qibili
# City not found. Skipping...
# Processing Record 45 of Set 10 | champoton
# Processing Record 46 of Set 10 | kargil
# Processing Record 47 of Set 10 | manzanillo
# Processing Record 48 of Set 10 | billings
# Processing Record 49 of Set 10 | srednekolymsk
# Processing Record 50 of Set 10 | raudeberg
# Processing Record 1 of Set 11 | padang
# Processing Record 2 of Set 11 | tianpeng
# Processing Record 3 of Set 11 | urucara
# Processing Record 4 of Set 11 | kurilsk
# Processing Record 5 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 11 | boueni
# Processing Record 7 of Set 11 | stettler
# Processing Record 8 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 11 | porbandar
# Processing Record 10 of Set 11 | prado
# Processing Record 11 of Set 11 | pacifica
# Processing Record 12 of Set 11 | viedma
# Processing Record 13 of Set 11 | zhob
# Processing Record 14 of Set 11 | macamic
# Processing Record 15 of Set 11 | margate
# Processing Record 16 of Set 11 | kharsawan
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | sandwick
# Processing Record 19 of Set 11 | mokhsogollokh
# Processing Record 20 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | bilibino
# Processing Record 22 of Set 11 | parana
# Processing Record 23 of Set 11 | bud
# Processing Record 24 of Set 11 | el porvenir
# Processing Record 25 of Set 11 | pasni
# Processing Record 26 of Set 11 | veraval
# Processing Record 27 of Set 11 | beidao
# Processing Record 28 of Set 11 | olafsvik
# Processing Record 29 of Set 11 | chernyshevskiy
# Processing Record 30 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 31 of Set 11 | nara
# Processing Record 32 of Set 11 | bandiagara
# Processing Record 33 of Set 11 | prescott
# Processing Record 34 of Set 11 | nanortalik
# Processing Record 35 of Set 11 | aras
# Processing Record 36 of Set 11 | bambous virieux
# Processing Record 37 of Set 11 | ak-dovurak
# Processing Record 38 of Set 11 | almora
# Processing Record 39 of Set 11 | vanimo
# Processing Record 40 of Set 11 | nago
# Processing Record 41 of Set 11 | bitkine
# Processing Record 42 of Set 11 | beringovskiy
# Processing Record 43 of Set 11 | menongue
# Processing Record 44 of Set 11 | bonfim
# Processing Record 45 of Set 11 | sarangani
# Processing Record 46 of Set 11 | nuuk
# Processing Record 47 of Set 11 | le passage
# Processing Record 48 of Set 11 | nadym
# Processing Record 49 of Set 11 | puerto madryn
# Processing Record 50 of Set 11 | walvis bay
# Processing Record 1 of Set 12 | hala
# Processing Record 2 of Set 12 | anshun
# Processing Record 3 of Set 12 | guiratinga
# Processing Record 4 of Set 12 | alyangula
# Processing Record 5 of Set 12 | baruun-urt
# Processing Record 6 of Set 12 | kingisepp
# Processing Record 7 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 12 | colares
# Processing Record 10 of Set 12 | makung
# City not found. Skipping...
# Processing Record 11 of Set 12 | puno
# Processing Record 12 of Set 12 | hoquiam
# Processing Record 13 of Set 12 | adrar
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | kansanshi
# Processing Record 16 of Set 12 | diffa
# Processing Record 17 of Set 12 | sinnamary
# Processing Record 18 of Set 12 | muisne
# Processing Record 19 of Set 12 | tezu
# Processing Record 20 of Set 12 | sampit
# Processing Record 21 of Set 12 | gbarnga
# Processing Record 22 of Set 12 | poum
# Processing Record 23 of Set 12 | xining
# Processing Record 24 of Set 12 | qandala
# Processing Record 25 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 12 | canico
# Processing Record 28 of Set 12 | ayan
# Processing Record 29 of Set 12 | galich
# Processing Record 30 of Set 12 | victoria point
# Processing Record 31 of Set 12 | morant bay
# Processing Record 32 of Set 12 | college
# Processing Record 33 of Set 12 | iskar
# Processing Record 34 of Set 12 | kudat
# Processing Record 35 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 12 | sao fidelis
# Processing Record 37 of Set 12 | khasan
# Processing Record 38 of Set 12 | aktau
# Processing Record 39 of Set 12 | capreol
# Processing Record 40 of Set 12 | cap malheureux
# Processing Record 41 of Set 12 | uruzgan
# Processing Record 42 of Set 12 | caravelas
# Processing Record 43 of Set 12 | negombo
# Processing Record 44 of Set 12 | sorland
# Processing Record 45 of Set 12 | lukulu
# Processing Record 46 of Set 12 | san cristobal
# Processing Record 47 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 12 | bathurst
# Processing Record 49 of Set 12 | tautira
# Processing Record 50 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 13 | hobyo
# Processing Record 2 of Set 13 | monrovia
# Processing Record 3 of Set 13 | ahtopol
# Processing Record 4 of Set 13 | knysna
# Processing Record 5 of Set 13 | nyrob
# Processing Record 6 of Set 13 | george
# Processing Record 7 of Set 13 | yenagoa
# Processing Record 8 of Set 13 | antofagasta
# Processing Record 9 of Set 13 | akyab
# Processing Record 10 of Set 13 | tual
# Processing Record 11 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 12 of Set 13 | nisia floresta
# Processing Record 13 of Set 13 | katangli
# Processing Record 14 of Set 13 | northam
# Processing Record 15 of Set 13 | huntington
# Processing Record 16 of Set 13 | qasigiannguit
# Processing Record 17 of Set 13 | tessalit
# Processing Record 18 of Set 13 | constitucion
# Processing Record 19 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 13 | nhulunbuy
# Processing Record 21 of Set 13 | sayyan
# Processing Record 22 of Set 13 | awjilah
# Processing Record 23 of Set 13 | bairiki
# Processing Record 24 of Set 13 | houston
# Processing Record 25 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 13 | mogzon
# Processing Record 27 of Set 13 | baherden
# Processing Record 28 of Set 13 | kuyanovo
# Processing Record 29 of Set 13 | paraiso
# Processing Record 30 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | isiro
# Processing Record 32 of Set 13 | bilma
# Processing Record 33 of Set 13 | resistencia
# Processing Record 34 of Set 13 | kerman
# Processing Record 35 of Set 13 | tilichiki
# Processing Record 36 of Set 13 | langres
# Processing Record 37 of Set 13 | richards bay
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | contai
# Processing Record 40 of Set 13 | kangasala
# Processing Record 41 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 13 | mutsu
# Processing Record 43 of Set 13 | havre-saint-pierre
# Processing Record 44 of Set 13 | erenhot
# Processing Record 45 of Set 13 | maningrida
# Processing Record 46 of Set 13 | nazarovo
# Processing Record 47 of Set 13 | qui nhon
# Processing Record 48 of Set 13 | kifri
# Processing Record 49 of Set 13 | usinsk
# Processing Record 50 of Set 13 | vestmanna
# Processing Record 1 of Set 14 | ajdabiya
# Processing Record 2 of Set 14 | batemans bay
# Processing Record 3 of Set 14 | porto murtinho
# Processing Record 4 of Set 14 | khoy
# Processing Record 5 of Set 14 | santa margherita ligure
# Processing Record 6 of Set 14 | jiancheng
# Processing Record 7 of Set 14 | shelburne
# Processing Record 8 of Set 14 | puri
# Processing Record 9 of Set 14 | berezovyy
# Processing Record 10 of Set 14 | mocuba
# Processing Record 11 of Set 14 | high rock
# Processing Record 12 of Set 14 | gao
# Processing Record 13 of Set 14 | outjo
# Processing Record 14 of Set 14 | bonavista
# Processing Record 15 of Set 14 | votkinsk
# Processing Record 16 of Set 14 | bubaque
# Processing Record 17 of Set 14 | labrea
# Processing Record 18 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 14 | kapiri mposhi
# Processing Record 20 of Set 14 | dunedin
# Processing Record 21 of Set 14 | vicuna
# Processing Record 22 of Set 14 | chimore
# Processing Record 23 of Set 14 | vagur
# Processing Record 24 of Set 14 | sotnikovo
# Processing Record 25 of Set 14 | kamenka
# Processing Record 26 of Set 14 | takoradi
# Processing Record 27 of Set 14 | sheridan
# Processing Record 28 of Set 14 | malanje
# Processing Record 29 of Set 14 | natyrbovo
# Processing Record 30 of Set 14 | seymchan
# Processing Record 31 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 14 | urfa
# City not found. Skipping...
# Processing Record 33 of Set 14 | chapleau
# Processing Record 34 of Set 14 | hami
# Processing Record 35 of Set 14 | toccoa
# Processing Record 36 of Set 14 | ndioum
# Processing Record 37 of Set 14 | baykit
# Processing Record 38 of Set 14 | tocopilla
# Processing Record 39 of Set 14 | manoel urbano
# Processing Record 40 of Set 14 | grand forks
# Processing Record 41 of Set 14 | jalu
# Processing Record 42 of Set 14 | mecca
# Processing Record 43 of Set 14 | new milford
# Processing Record 44 of Set 14 | novyy urengoy
# Processing Record 45 of Set 14 | manggar
# Processing Record 46 of Set 14 | prince rupert
# Processing Record 47 of Set 14 | bhawanipatna
# Processing Record 48 of Set 14 | tokur
# Processing Record 49 of Set 14 | balykshi
# Processing Record 50 of Set 14 | meulaboh
# Processing Record 1 of Set 15 | flinders
# Processing Record 2 of Set 15 | chapada dos guimaraes
# Processing Record 3 of Set 15 | svilajnac
# Processing Record 4 of Set 15 | gumdag
# Processing Record 5 of Set 15 | odda
# Processing Record 6 of Set 15 | honningsvag
# Processing Record 7 of Set 15 | sergeyevka
# Processing Record 8 of Set 15 | manitouwadge
# Processing Record 9 of Set 15 | jijiang
# Processing Record 10 of Set 15 | ngunguru
# Processing Record 11 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 12 of Set 15 | niamey
# Processing Record 13 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 15 | kushima
# Processing Record 15 of Set 15 | cockburn town
# Processing Record 16 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 15 | bombay
# Processing Record 18 of Set 15 | saint-jean-de-luz
# Processing Record 19 of Set 15 | yongan
# Processing Record 20 of Set 15 | pemangkat
# Processing Record 21 of Set 15 | gourcy
# Processing Record 22 of Set 15 | tuatapere
# Processing Record 23 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 24 of Set 15 | liuzhou
# Processing Record 25 of Set 15 | urla
# Processing Record 26 of Set 15 | alice town
# Processing Record 27 of Set 15 | jaru
# Processing Record 28 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 15 | dhidhdhoo
# Processing Record 30 of Set 15 | vodnyy
# Processing Record 31 of Set 15 | nurlat
# Processing Record 32 of Set 15 | pontes e lacerda
# Processing Record 33 of Set 15 | saposoa
# Processing Record 34 of Set 15 | bjornevatn
# Processing Record 35 of Set 15 | teopantlan
# Processing Record 36 of Set 15 | sazonovo
# Processing Record 37 of Set 15 | los algarrobos
# Processing Record 38 of Set 15 | kulpahar
# Processing Record 39 of Set 15 | kikerino
# Processing Record 40 of Set 15 | puerto penasco
# Processing Record 41 of Set 15 | plastun
# Processing Record 42 of Set 15 | kodinsk
# Processing Record 43 of Set 15 | gamba
# Processing Record 44 of Set 15 | sola
# Processing Record 45 of Set 15 | davidson
# Processing Record 46 of Set 15 | sungaipenuh
# Processing Record 47 of Set 15 | sinnar
# Processing Record 48 of Set 15 | proletarskiy
# Processing Record 49 of Set 15 | llandrindod wells
# Processing Record 50 of Set 15 | pinerolo
# Processing Record 1 of Set 16 | puerto carreno
# Processing Record 2 of Set 16 | kirensk
# Processing Record 3 of Set 16 | tshikapa
# Processing Record 4 of Set 16 | puerto narino
# Processing Record 5 of Set 16 | buraydah
# Processing Record 6 of Set 16 | purpe
# Processing Record 7 of Set 16 | rediu
# Processing Record 8 of Set 16 | porto novo
# Processing Record 9 of Set 16 | choya
# Processing Record 10 of Set 16 | srandakan
# Processing Record 11 of Set 16 | terrace
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vila Velha -20.3297  -40.2925     73.94        77          75
# 1        El Llano  20.0500  -99.3000     74.43        18           5
# 2  Atlantic Beach  30.3344  -81.3987     73.62        87          40
# 3        Akureyri  65.6835  -18.0878      6.73        92          20
# 4        Hermanus -34.4187   19.2345     71.80        88          94
# 5         Rikitea -23.1203 -134.9692     74.26        76          91
# 6           Bluff -46.6000  168.3333     63.81        81          98
# 7      Las Palmas  28.4204  -14.0131     63.39        68          40
# 8         Waipawa -41.4122  175.5153     70.56        70         100
# 9           Sitka  57.0531 -135.3300     42.69        93         100
#
#    Wind Speed Country       Description
# 0        4.61      BR     broken clouds
# 1        5.86      MX         clear sky
# 2       13.80      US  scattered clouds
# 3        2.30      IS        few clouds
# 4        6.64      ZA        light rain
# 5        9.08      PF   overcast clouds
# 6        6.44      NZ     moderate rain
# 7        4.61      ES  scattered clouds
# 8        7.81      NZ     moderate rain
# 9       10.36      US              mist

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vila Velha      BR -20.3297  -40.2925     73.94        77          75
# 1        El Llano      MX  20.0500  -99.3000     74.43        18           5
# 2  Atlantic Beach      US  30.3344  -81.3987     73.62        87          40
# 3        Akureyri      IS  65.6835  -18.0878      6.73        92          20
# 4        Hermanus      ZA -34.4187   19.2345     71.80        88          94
# 5         Rikitea      PF -23.1203 -134.9692     74.26        76          91
# 6           Bluff      NZ -46.6000  168.3333     63.81        81          98
# 7      Las Palmas      ES  28.4204  -14.0131     63.39        68          40
# 8         Waipawa      NZ -41.4122  175.5153     70.56        70         100
# 9           Sitka      US  57.0531 -135.3300     42.69        93         100
#
#    Wind Speed       Description
# 0        4.61     broken clouds
# 1        5.86         clear sky
# 2       13.80  scattered clouds
# 3        2.30        few clouds
# 4        6.64        light rain
# 5        9.08   overcast clouds
# 6        6.44     moderate rain
# 7        4.61  scattered clouds
# 8        7.81     moderate rain
# 9       10.36              mist

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPY_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
